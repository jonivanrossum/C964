# %% [markdown]
# # C964 -- Song Popularity Predictor

# %% [markdown]
# ## Setting Up Environment and Importing All Required Libraries

# %%
# for data manipulations
import numpy as np
import pandas as pd

# for data visualizations
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('fivethirtyeight')

# for interactivity
import ipywidgets
from ipywidgets import interact

import os

small_figsize = (14, 7)
large_figsize = (18, 18)
plt.rcParams['figure.figsize'] = small_figsize

from warnings import filterwarnings as warnings

# import gzip, pickletools
import pickle
from imblearn.over_sampling import SMOTE
# from sklearn.preprocessing import MinMaxScaler
from sklearn.linear_model import *
from sklearn.metrics import mean_absolute_error, confusion_matrix, accuracy_score, classification_report, balanced_accuracy_score
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import BaggingClassifier, RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import GridSearchCV, cross_val_score, train_test_split

# %%
# Load the track data using pandas
track_data = pd.read_csv('Data Sources/spotify_tracks.csv')
artist_data = pd.read_csv('Data Sources/spotify_artists.csv')
album_data = pd.read_csv('Data Sources/spotify_albums.csv')

# %%
# Exploring track data by getting a sample from the dataset
track_data.sample(2)
# Out:
#        Unnamed: 0  acousticness                album_id  \
# 26475       26475        0.1790  4DyMK9x2gnmRkRa16zHaEV
# 48978       48978        0.0262  6Ic6POkctMk9dyvr75zd7F
#
#                                             analysis_url  \
# 26475  https://api.spotify.com/v1/audio-analysis/3TY1...
# 48978  https://api.spotify.com/v1/audio-analysis/7sYN...
#
#                        artists_id  \
# 26475  ['0EmeFodog0BfCgMzAIvKQp']
# 48978  ['1zLMhO4zzzxt5PMV4wMS3y']
#
#                                        available_markets country  \
# 26475  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE
# 48978                                 ['AT', 'CH', 'DE']      FI
#
#        danceability  disc_number  duration_ms  ...  \
# 26475         0.767          1.0     194107.0  ...
# 48978         0.739          1.0     194967.0  ...
#
#                                              preview_url speechiness    tempo  \
# 26475  https://p.scdn.co/mp3-preview/400a0dae84995926...      0.0336  108.973
# 48978  https://p.scdn.co/mp3-preview/e49e49526bce8caf...      0.0460  124.977
#
#        time_signature                                         track_href  \
# 26475             4.0  https://api.spotify.com/v1/tracks/3TY1PFZXmYei...
# 48978             4.0  https://api.spotify.com/v1/tracks/7sYNbAMvpcgA...
#
#        track_name_prev  track_number                                   uri  \
# 26475         track_19          12.0  spotify:track:3TY1PFZXmYeiLcXygB74My
# 48978         track_23           1.0  spotify:track:7sYNbAMvpcgAZkti8KTuqt
#
#        valence   type
# 26475    0.892  track
# 48978    0.460  track
#
# [2 rows x 32 columns]

# %%
# Exploring artist data by getting a sample from the dataset
artist_data.sample(2)
# Out:
#        Unnamed: 0  artist_popularity  followers                      genres  \
# 28332       28332                 33      24047         ['portuguese rock']
# 6795         6795                 42       7093  ['uk alternative hip hop']
#
#                            id          name                track_id  \
# 28332  580DM82FybhvbJYUtEjkEz  Os Azeitonas  6tLAA0oKfcN7DNgcuIAYbD
# 6795   7qffELscxpltKCso3ByH67        Flohio  04983qPpPoUMmLeN06yLto
#
#       track_name_prev    type
# 28332        track_15  artist
# 6795         track_27  artist

# %%
# Exploring album data by getting a sample from the dataset
album_data.sample(2)
# Out:
#        Unnamed: 0   album_type               artist_id  \
# 13304       13304  compilation  0LyfQWJT6nXafLPZqxe9Of
# 27988       27988       single  6BgObl0N7gA4H9i5cYkcSt
#
#                                        available_markets  \
# 13304  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
# 27988  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...
#
#                                            external_urls  \
# 13304  {'spotify': 'https://open.spotify.com/album/2F...
# 27988  {'spotify': 'https://open.spotify.com/album/7m...
#
#                                                     href  \
# 13304  https://api.spotify.com/v1/albums/2F0HgryBMVR6...
# 27988  https://api.spotify.com/v1/albums/7mdmGPE4Ec8q...
#
#                            id  \
# 13304  2F0HgryBMVR6AY79ajK8qU
# 27988  7mdmGPE4Ec8qr0GZzydTft
#
#                                                   images             name  \
# 13304  [{'height': 640, 'url': 'https://i.scdn.co/ima...  Our New Orleans
# 27988  [{'height': 640, 'url': 'https://i.scdn.co/ima...        Dumbo NYC
#
#       release_date release_date_precision  total_tracks  \
# 13304   2005-12-05                    day            16
# 27988   2018-05-17                    day             1
#
#                      track_id track_name_prev  \
# 13304  65sPImCpuvhK21doidXxS0         track_9
# 27988  1r9Pjr6S5cbtbGqg4ggqot         track_5
#
#                                         uri   type
# 13304  spotify:album:2F0HgryBMVR6AY79ajK8qU  album
# 27988  spotify:album:7mdmGPE4Ec8qr0GZzydTft  album

# %% [markdown]
# ## Preparing the Dataset

# %%
# check for what columns we have in all dataframes and select which ones we want to use for prediction
print("Columns present in track_data:", track_data.columns)
print("Columns present in artist_data:", artist_data.columns)
print("Columns present in album_data:", album_data.columns)
# Out:
# Columns present in track_data: Index(['Unnamed: 0', 'acousticness', 'album_id', 'analysis_url', 'artists_id',
#        'available_markets', 'country', 'danceability', 'disc_number',
#        'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'lyrics', 'mode', 'name', 'playlist',
#        'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature',
#        'track_href', 'track_name_prev', 'track_number', 'uri', 'valence',
#        'type'],
#       dtype='object')
# Columns present in artist_data: Index(['Unnamed: 0', 'artist_popularity', 'followers', 'genres', 'id', 'name',
#        'track_id', 'track_name_prev', 'type'],
#       dtype='object')
# Columns present in album_data: Index(['Unnamed: 0', 'album_type', 'artist_id', 'available_markets',
#        'external_urls', 'href', 'id', 'images', 'name', 'release_date',
#        'release_date_precision', 'total_tracks', 'track_id', 'track_name_prev',
#        'uri', 'type'],
#       dtype='object')

# %%
# let's join track data and artist data, but all we need from the artist dataset is 'genres'
song_data = pd.merge(track_data, artist_data[['track_id', 'genres']], left_on='id', right_on='track_id', how='inner')

# drop 'track_id' column, because we don't need it anymore.
song_data.drop('track_id', axis=1, inplace=True)

# check song_data head
song_data.head(3)
# Out:
#    Unnamed: 0  acousticness                album_id  \
# 0           1         0.863  1bcqsH5UyTBzmh9YizdsBE
# 1           3         0.763  6FeJF5r8roonnKraJxr4oB
# 2          10         0.101  7noNViHJAYZ3UxlhDNKAt9
#
#                                         analysis_url  \
# 0  https://api.spotify.com/v1/audio-analysis/3VAX...
# 1  https://api.spotify.com/v1/audio-analysis/6aCe...
# 2  https://api.spotify.com/v1/audio-analysis/01zM...
#
#                                           artists_id  \
# 0                         ['4xWMewm6CYMstu0sPgd9jJ']
# 1                         ['2KQsUB9DRBcJk17JWX1eXD']
# 2  ['3FLUBwpAnaIlIKeaBfsxFe', '5r5Va4lVQ1zjEfbJSr...
#
#                                    available_markets country  danceability  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.719
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.719
# 2  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.748
#
#    disc_number  duration_ms  ...  speechiness    tempo time_signature  \
# 0          1.0     656960.0  ...       0.9220  115.075            3.0
# 1          1.0     316578.0  ...       0.9380  112.822            3.0
# 2          1.0     237667.0  ...       0.0833  114.982            4.0
#
#                                           track_href  track_name_prev  \
# 0  https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...          track_3
# 1  https://api.spotify.com/v1/tracks/6aCe9zzoZmCo...          track_9
# 2  https://api.spotify.com/v1/tracks/01zME4q62SDP...         track_42
#
#    track_number                                   uri valence   type  \
# 0           3.0  spotify:track:3VAX2MJdmdqARLSU5hPMpm   0.589  track
# 1           1.0  spotify:track:6aCe9zzoZmCojX7bbgKKtf   0.533  track
# 2           1.0  spotify:track:01zME4q62SDPtD0hOSmTrG   0.359  track
#
#                              genres
# 0                                []
# 1  ['german literature', 'reading']
# 2                       ['electra']
#
# [3 rows x 33 columns]

# %%
# now we'll merge song_data with the album data release date
song_data = pd.merge(song_data, album_data[['track_id', 'release_date']], left_on='id', right_on='track_id', how='inner')

# drop 'track_id' column again, because we don't need it anymore.
song_data.drop('track_id', axis=1, inplace=True)

# check song_data head
song_data.head()
# Out:
#    Unnamed: 0  acousticness                album_id  \
# 0           1        0.8630  1bcqsH5UyTBzmh9YizdsBE
# 1          10        0.1010  7noNViHJAYZ3UxlhDNKAt9
# 2          25        0.1910  6cflCkqI3e9MHkm7rZlkXA
# 3          28        0.6780  6VVr09AK8qjO6doYUEzrVj
# 4          35        0.0786  6HliYi1SE9uMcnJHFVC0oT
#
#                                         analysis_url  \
# 0  https://api.spotify.com/v1/audio-analysis/3VAX...
# 1  https://api.spotify.com/v1/audio-analysis/01zM...
# 2  https://api.spotify.com/v1/audio-analysis/2Dh5...
# 3  https://api.spotify.com/v1/audio-analysis/2hX9...
# 4  https://api.spotify.com/v1/audio-analysis/58QD...
#
#                                           artists_id  \
# 0                         ['4xWMewm6CYMstu0sPgd9jJ']
# 1  ['3FLUBwpAnaIlIKeaBfsxFe', '5r5Va4lVQ1zjEfbJSr...
# 2                         ['06Iig2bqY8mv98B1c9Iyo8']
# 3                         ['7mdXCgprfvNzxRQsjuUwy8']
# 4                         ['04XdCDDrPnnqidaVBTOQjt']
#
#                                    available_markets country  danceability  \
# 0  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.719
# 1  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.748
# 2  ['AD', 'AT', 'BE', 'BG', 'CH', 'CY', 'CZ', 'DE...      BE         0.608
# 3  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.679
# 4  ['AD', 'AE', 'AR', 'AT', 'AU', 'BE', 'BG', 'BH...      BE         0.470
#
#    disc_number  duration_ms  ...    tempo time_signature  \
# 0          1.0     656960.0  ...  115.075            3.0
# 1          1.0     237667.0  ...  114.982            4.0
# 2          1.0     243667.0  ...  100.011            4.0
# 3          1.0     587465.0  ...  100.846            4.0
# 4          1.0     157500.0  ...   96.149            4.0
#
#                                           track_href  track_name_prev  \
# 0  https://api.spotify.com/v1/tracks/3VAX2MJdmdqA...          track_3
# 1  https://api.spotify.com/v1/tracks/01zME4q62SDP...         track_42
# 2  https://api.spotify.com/v1/tracks/2Dh5wED4UVei...         track_60
# 3  https://api.spotify.com/v1/tracks/2hX9xFhvz0LT...         track_29
# 4  https://api.spotify.com/v1/tracks/58QDB1sKe1wH...          track_6
#
#    track_number                                   uri  valence   type  \
# 0           3.0  spotify:track:3VAX2MJdmdqARLSU5hPMpm    0.589  track
# 1           1.0  spotify:track:01zME4q62SDPtD0hOSmTrG    0.359  track
# 2           1.0  spotify:track:2Dh5wED4UVeiBqneUdc5Gy    0.513  track
# 3           2.0  spotify:track:2hX9xFhvz0LTYJ7KvcENMl    0.397  track
# 4           1.0  spotify:track:58QDB1sKe1wHZEvngevtGE    0.856  track
#
#                                            genres release_date
# 0                                              []   2011-03-01
# 1                                     ['electra']   2018-09-07
# 2  ['dreamgaze', 'nu gaze', 'swedish indie rock']   2018-06-22
# 3                                              []   2010-02-01
# 4                ['cumbia pop', 'cumbia villera']   2018-12-21
#
# [5 rows x 34 columns]

# %%
# let's check what columns are present no in teh dataframe
song_data.columns
# Out:
# Index(['Unnamed: 0', 'acousticness', 'album_id', 'analysis_url', 'artists_id',
#        'available_markets', 'country', 'danceability', 'disc_number',
#        'duration_ms', 'energy', 'href', 'id', 'instrumentalness', 'key',
#        'liveness', 'loudness', 'lyrics', 'mode', 'name', 'playlist',
#        'popularity', 'preview_url', 'speechiness', 'tempo', 'time_signature',
#        'track_href', 'track_name_prev', 'track_number', 'uri', 'valence',
#        'type', 'genres', 'release_date'],
#       dtype='object')

# %% [markdown]
# Merging the data was a succes!

# %%
# Let's drop columns we don't need for our predictor
data = song_data.drop(['Unnamed: 0',
                     'album_id',
                     'analysis_url',
                     'artists_id',
                     'available_markets',
                     'country',
                     'disc_number',
                     'href',
                     'id',
                     'lyrics',
                     'name',
                     'playlist',
                     'track_href',
                     'preview_url',
                     'track_href',
                     'track_name_prev',
                     'track_number',
                     'uri',
                     'type',], axis=1)

data.columns
# Out:
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'genres',
#        'release_date'],
#       dtype='object')

# %%
# create a new column 'release_year' and drop 'release_date'
data['release_date'] = pd.to_datetime(data['release_date'])
data['release_year'] = data.release_date.dt.year
data.drop('release_date', axis=1, inplace=True)
data.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.8630         0.719     656960.0   0.308          0.000000  6.0
# 1        0.1010         0.748     237667.0   0.666          0.000653  6.0
# 2        0.1910         0.608     243667.0   0.664          0.042700  5.0
# 3        0.6780         0.679     587465.0   0.247          0.000001  7.0
# 4        0.0786         0.470     157500.0   0.828          0.000000  9.0
#
#    liveness  loudness  mode  popularity  speechiness    tempo  time_signature  \
# 0    0.2530   -10.340   1.0        31.0       0.9220  115.075             3.0
# 1    0.0976    -6.094   0.0        47.0       0.0833  114.982             4.0
# 2    0.1200    -8.261   0.0        35.0       0.0435  100.011             4.0
# 3    0.1790   -21.546   1.0         7.0       0.9240  100.846             4.0
# 4    0.1780    -6.280   1.0        55.0       0.0700   96.149             4.0
#
#    valence                                          genres  release_year
# 0    0.589                                              []          2011
# 1    0.359                                     ['electra']          2018
# 2    0.513  ['dreamgaze', 'nu gaze', 'swedish indie rock']          2018
# 3    0.397                                              []          2010
# 4    0.856                ['cumbia pop', 'cumbia villera']          2018

# %%
data.describe()
# Out:
#        acousticness  danceability   duration_ms        energy  \
# count  53247.000000  53247.000000  5.324700e+04  53247.000000
# mean       0.352891      0.575549  2.551591e+05      0.584284
# std        0.350893      0.192521  1.876593e+05      0.269966
# min        0.000000      0.000000  4.000000e+03      0.000000
# 25%        0.032500      0.454000  1.868595e+05      0.408000
# 50%        0.213000      0.603000  2.193330e+05      0.636000
# 75%        0.670000      0.723000  2.700490e+05      0.802000
# max        0.996000      0.984000  4.811520e+06      1.000000
#
#        instrumentalness           key      liveness      loudness  \
# count      53247.000000  53247.000000  53247.000000  53247.000000
# mean           0.193634      5.267189      0.182994     -9.685067
# std            0.332821      3.560689      0.155679      6.463120
# min            0.000000      0.000000      0.000000    -57.436000
# 25%            0.000000      2.000000      0.093400    -11.311000
# 50%            0.000237      5.000000      0.119000     -7.680000
# 75%            0.233000      8.000000      0.219000     -5.528000
# max            1.000000     11.000000      0.999000      1.605000
#
#                mode    popularity   speechiness         tempo  time_signature  \
# count  53247.000000  53247.000000  53247.000000  53247.000000    53247.000000
# mean       0.592315     37.094935      0.095065    118.687106        3.895299
# std        0.491409     15.552253      0.117811     29.267361        0.447258
# min        0.000000      0.000000      0.000000      0.000000        0.000000
# 25%        0.000000     26.000000      0.037700     96.477000        4.000000
# 50%        1.000000     37.000000      0.050700    119.574000        4.000000
# 75%        1.000000     48.000000      0.094300    135.952000        4.000000
# max        1.000000     95.000000      0.964000    244.035000        5.000000
#
#             valence  release_year
# count  53247.000000  53247.000000
# mean       0.461640   2013.260860
# std        0.267264      9.314505
# min        0.000000   1886.000000
# 25%        0.237000   2012.000000
# 50%        0.454000   2017.000000
# 75%        0.678000   2018.000000
# max        0.993000   2019.000000

# %% [markdown]
# Music Popularity is very time sensitive and follows trends. What was popular 20 years ago is not always popular now. So let's work with a dataset that only has songs from 2015 on. Five years of songs intuitively seems a good number (the dataset only has songs up until 2019).

# %%
# data shape before dropping rows
x = list(data.shape)
print("Data shape before dropping rows", x)

# Select songs from 2015 and after
df = data[data['release_year'] >= 2015]

# data shape after dropping rows
y = list(df.shape)
print("Data shape after dropping rows", y)

def rows_dropped_report(x, y):
    z = x[0] - y[0]
    return z

print(f"A total of {rows_dropped_report(x, y)} rows were dropped.")
# Out:
# Data shape before dropping rows [53247, 16]
# Data shape after dropping rows [36575, 16]
# A total of 16672 rows were dropped.

# %% [markdown]
# ## Exploring the Data

# %%
# let's check what datatypes are present in the dataset 
df.dtypes
# Out:
# acousticness        float64
# danceability        float64
# duration_ms         float64
# energy              float64
# instrumentalness    float64
# key                 float64
# liveness            float64
# loudness            float64
# mode                float64
# popularity          float64
# speechiness         float64
# tempo               float64
# time_signature      float64
# valence             float64
# genres               object
# release_year          int64
# dtype: object

# %%
# %%time


# let's explore what the genres column holds
df['genres'].value_counts()
# Out:
# []                                                                                       16764
# ['focus']                                                                                  171
# ['chillhop', 'lo-fi beats']                                                                 95
# ['lo-fi beats']                                                                             68
# ['dutch hip hop']                                                                           67
#                                                                                          ...
# ['bass music', 'chillwave', 'grave wave', 'witch house', 'wonky']                            1
# ['art pop', 'chamber psych', 'escape room', 'fluxwork']                                      1
# ['no wave', 'norwegian indie', 'norwegian pop', 'norwegian pop rap']                         1
# ['boston hardcore', 'chaotic hardcore', 'grindcore', 'mathcore', 'post-doom metal']          1
# ['atl hip hop', 'hip hop', 'pop', 'pop rap', 'rap', 'southern hip hop', 'trap music']        1
# Name: genres, Length: 8051, dtype: int64

# %% [markdown]
# In our 31000+ records, more than 14000 have an empty list as a genre. This is not a workable situation, so let's drop the genre column altogether. It's really too bad, as genre can be of influence to popularity.

# %%
df.drop('genres', inplace=True, axis=1)

# check if genres column was indeed dropped
df.columns
# Out:
# /var/folders/0z/xjhgll894vxgph2wykg858lr0000gq/T/ipykernel_74397/1265756408.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop('genres', inplace=True, axis=1)
# Index(['acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode', 'popularity',
#        'speechiness', 'tempo', 'time_signature', 'valence', 'release_year'],
#       dtype='object')

# %% [markdown]
# Let's see if there are songs that have 0 popularity. After all, we are trying to see what makes a song popular, not what makes it unpopular. This will probably cut out some noise too.

# %%
# let's see if there are songs that have 0 popularity
df[df['popularity'] == 0]
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness  \
# 598        0.059500         0.000       6500.0   0.477          0.000000
# 937        0.677000         0.000       4750.0   0.366          0.122000
# 1446       0.821000         0.000       6250.0   0.226          0.000000
# 1859       0.186000         0.421     274644.0   0.692          0.000000
# 1860       0.186000         0.421     274644.0   0.692          0.000000
# ...             ...           ...          ...     ...               ...
# 51341      0.000337         0.833     266148.0   0.698          0.346000
# 51968      0.227000         0.404     233860.0   0.427          0.856000
# 52164      0.021100         0.715     254733.0   0.970          0.000019
# 52173      0.007200         0.720     222587.0   0.878          0.000001
# 52506      0.007510         0.382     161613.0   0.931          0.000105
#
#         key  liveness  loudness  mode  popularity  speechiness    tempo  \
# 598     3.0    0.0000   -12.187   1.0         0.0       0.0000    0.000
# 937    10.0    0.0000   -14.910   0.0         0.0       0.0000    0.000
# 1446    3.0    0.0000    -9.586   0.0         0.0       0.0000    0.000
# 1859    2.0    0.2940    -5.721   0.0         0.0       0.0869  116.480
# 1860    2.0    0.2940    -5.721   0.0         0.0       0.0869  116.480
# ...     ...       ...       ...   ...         ...          ...      ...
# 51341  10.0    0.1360    -5.266   0.0         0.0       0.0520  122.980
# 51968   2.0    0.0907   -12.578   1.0         0.0       0.0683  162.668
# 52164   0.0    0.3350    -2.270   0.0         0.0       0.0467  108.005
# 52173   7.0    0.2810    -4.930   0.0         0.0       0.1680  125.990
# 52506   7.0    0.2360    -5.952   1.0         0.0       0.0652   90.618
#
#        time_signature  valence  release_year
# 598               0.0   0.0000          2018
# 937               0.0   0.0000          2018
# 1446              0.0   0.0000          2018
# 1859              4.0   0.4960          2016
# 1860              4.0   0.4960          2016
# ...               ...      ...           ...
# 51341             4.0   0.2360          2019
# 51968             4.0   0.0388          2019
# 52164             4.0   0.8020          2019
# 52173             4.0   0.6210          2019
# 52506             4.0   0.3580          2018
#
# [140 rows x 15 columns]

# %% [markdown]
# That query returned 128 rows. Let's delete them and then categorize the remaining rows by popularity rating.

# %%
# data shape before dropping rows
x = list(df.shape)
print("Data shape before dropping rows", x)

# Drop rows with 0 popularity
df = df[df['popularity'] > 0]

# data shape after dropping rows
y = list(df.shape)
print("Data shape after dropping rows", y)

print(f"A total of {rows_dropped_report(x, y)} rows were dropped.")
# Out:
# Data shape before dropping rows [36575, 15]
# Data shape after dropping rows [36435, 15]
# A total of 140 rows were dropped.

# %% [markdown]
# Let's split the popularity observations into 3 classes:
# * Unpopular
# * Popular
# * Very Popular

# %%
df['pop_rating'] = ''
# Out:
# /var/folders/0z/xjhgll894vxgph2wykg858lr0000gq/T/ipykernel_74397/721276715.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pop_rating'] = ''

# %%
pop_ratings = ['Unpopular', 'Popular', 'Very Popular']

for i, row in df.iterrows():
    score = pop_ratings[0]
    if (row.popularity >= 80):
        score = pop_ratings[2]
    elif (row.popularity >= 50 and row.popularity < 80):
        score = pop_ratings[1]
# elif (row.popularity > 20 and row.popularity < 40):
#        score = 'Somewhat Popular''''
    df.at[i, 'pop_rating'] = score
    
df[['popularity', 'pop_rating']].head()
# Out:
#    popularity pop_rating
# 1        47.0  Unpopular
# 2        35.0  Unpopular
# 4        55.0    Popular
# 6        41.0  Unpopular
# 7        49.0  Unpopular

# %%
df.pop_rating.describe()
# Out:
# count         36435
# unique            3
# top       Unpopular
# freq          27969
# Name: pop_rating, dtype: object

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# Let's check for null values first:

# %%
print(df.isnull().sum(), "\n")
print(df.isna().sum())
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# popularity          0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# release_year        0
# pop_rating          0
# dtype: int64
#
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# popularity          0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# release_year        0
# pop_rating          0
# dtype: int64

# %% [markdown]
# There are no missing values in the dataset.

# %% [markdown]
# Since "popularity" is the target column, let's see what we have:

# %%
df['pop_rating'] = pd.Categorical(df.pop_rating, pop_ratings)

plt.rcParams['figure.figsize'] = small_figsize

plt.subplot(1, 2, 1)
sns.histplot(x=df.popularity, color = 'purple', kde=True)
plt.xlabel('Popularity', fontsize = 15)
plt.title("Distribution of Popularity", fontsize=16)
plt.grid()

plt.subplot(1, 2, 2)
sns.countplot(x=df.pop_rating, color = 'darkgreen')
plt.xlabel('Popularity Rating', fontsize = 15)
plt.title("Distribution of Popularity Rating", fontsize=16)
plt.grid()

plt.suptitle("Distribution of Popularity and Popularity Rating", fontsize=20)
plt.show()
# Out:
# /var/folders/0z/xjhgll894vxgph2wykg858lr0000gq/T/ipykernel_74397/3891402888.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['pop_rating'] = pd.Categorical(df.pop_rating, pop_ratings)

# %% [markdown]
# The popularity columns looks pretty much like a normal distribution.

# %% [markdown]
# ### Descriptive Statistics

# %%
print("Average Ratio of Acousticness in the Dataset: {0:.2f}".format(df['acousticness'].mean()))
print("Average Ratio of Danceability in the Dataset: {0:.2f}".format(df['danceability'].mean()))
minutes = int((df['duration_ms'].mean()//1000)//60)
seconds = int((df['duration_ms'].mean()//1000)%60)
print("Average Duration of Songs:", minutes, "minutes and", seconds, "seconds")
print("Average Ratio of Energy in the Dataset: {0:.2f}".format(df['energy'].mean()))
print("Average Ratio of Instrumentalness in the Dataset: {0:.2f}".format(df['instrumentalness'].mean()))
print("Average Ratio of Liveness in the Dataset: {0:.2f}".format(df['liveness'].mean()))
print("Average Ratio of Loudness in the Dataset: {0:.2f}".format(df['loudness'].mean()))
print("Average Ratio of Speechiness in the Dataset: {0:.2f}".format(df['speechiness'].mean()))
print("Average Tempo in the Dataset: {0:.2f}".format(df['tempo'].mean()), "bpm")
print("Average Ratio of Valence in the Dataset: {0:.2f}".format(df['valence'].mean()))
print("Average Popularity in the Dataset: {0:.2f}".format(df['popularity'].mean()))
# Out:
# Average Ratio of Acousticness in the Dataset: 0.29
# Average Ratio of Danceability in the Dataset: 0.60
# Average Duration of Songs: 3 minutes and 53 seconds
# Average Ratio of Energy in the Dataset: 0.62
# Average Ratio of Instrumentalness in the Dataset: 0.18
# Average Ratio of Liveness in the Dataset: 0.18
# Average Ratio of Loudness in the Dataset: -8.42
# Average Ratio of Speechiness in the Dataset: 0.10
# Average Tempo in the Dataset: 120.22 bpm
# Average Ratio of Valence in the Dataset: 0.46
# Average Popularity in the Dataset: 38.55

# %% [markdown]
# ### Univariate Analysis

# %%
# check distribution of different categories in the dataset

plt.rcParams['figure.figsize'] = large_figsize

plt.subplot(5, 2, 1)
sns.histplot(df['acousticness'], color = 'lightgrey', kde=True)
plt.xlabel('Acousticness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 2)
sns.histplot(df['danceability'], color = 'skyblue', kde=True)
plt.xlabel('Danceability', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 3)
sns.histplot(df['duration_ms'], color ='darkblue', kde=True)
plt.xlabel('duration_ms', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 4)
sns.histplot(df['energy'], color = 'black', kde=True)
plt.xlabel('Energy', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 5)
sns.histplot(df['instrumentalness'], color = 'grey', kde=True)
plt.xlabel('Instrumentalness', fontsize = 12)
plt.ylim(0, 1000)
plt.grid()

plt.subplot(5, 2, 6)
sns.histplot(df['liveness'], color = 'lightgreen', kde=True)
plt.xlabel('Liveness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 7)
sns.histplot(df['loudness'], color = 'darkgreen', kde=True)
plt.xlabel('Loudness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 8)
sns.histplot(df['speechiness'], color = 'purple', kde=True)
plt.xlabel('Speechiness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 9)
sns.histplot(df['tempo'], color = 'orange', kde=True)
plt.xlabel('Tempo', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 10)
sns.histplot(df['valence'], color = 'cyan', kde=True)
plt.xlabel('Valence', fontsize = 12)
plt.grid()

plt.suptitle('Distribution for Music Attributes', fontsize = 20)
plt.show()

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# When checking for correlation, a heatmap is useful:

# %%
plt.rcParams['figure.figsize'] = small_figsize
sns.heatmap(df.corr(), annot=True, cmap='copper')
plt.title("Correlation of Music Attributes")
plt.show()

# %% [markdown]
# No attribute strongly relates to Popularity.

# %%
# Define a function to help plot a scatterplot using given inputs 
def scat_plot(x, y, hue=None, xlabel='', ylabel='', title=''):
    '''Plots a scatterplot using given inputs'''
    fig, ax = plt.subplots(figsize=(12, 6))
    _ = sns.scatterplot(x=x, y=y, hue=hue, s=14)
    _ = plt.xlabel(xlabel, fontsize=14)
    _ = plt.ylabel(ylabel, fontsize=14)
    _ = plt.title(title, fontsize=20)
    _ = plt.legend(fontsize=14)
    plt.show()
    
# Define a function to help plot a scatterplot with a regression line using given inputs 
def regress_plot(x='', y='', data=None, xlabel='', ylabel='', title=''):
    '''Plots a scatterplot with a regression line
    using given inputs'''
    fig, ax = plt.subplots(figsize=(12, 6))
    _ = sns.regplot(x=x, y=y, data=data, scatter_kws={"s": 10}, line_kws={'color':'r'})
    _ = plt.xlabel(xlabel, fontsize=14)
    _ = plt.ylabel(ylabel, fontsize=14)
    _ = plt.title(title, fontsize=20)
    _ = plt.ylim(-3, 103)
    plt.show()

# %%
scat_plot(df.loudness, df.popularity, hue=df.pop_rating, ylabel="Popularity",
         xlabel="Loudness", title="Loudness vs. Popularity")

# %% [markdown]
# This scatterplot is more dense toward higher levels of loudness. Loudness may not guarantee popularity, but it seems the odds are greater for loud songs than songs that have low levels of loudness.

# %%
regress_plot(df.loudness, df.popularity, data=df, ylabel="Popularity",
         xlabel="Loudness", title="Loudness vs. Popularity")

# %% [markdown]
# The regressor shows there is somewhat of a positive correlation, but it's not a very strong fit.

# %% [markdown]
# According to the heatmap, Popularity is stronger correlated to Energy than Loudness, so let's check what that is about:

# %%
scat_plot(df.energy, df.popularity, hue=df.pop_rating,
          xlabel="Energy",
          ylabel="Popularity", 
          title="Energy vs. Popularity")

# %%
regress_plot(df.energy, df.popularity, data=df,
          xlabel="Energy",
          ylabel="Popularity", 
          title="Energy vs. Popularity")

# %% [markdown]
# Even though the regressor trends downwards, it seems that the most popular songs are high energy.

# %%
# Categorical vs. Numerical
plt.rcParams['figure.figsize'] = large_figsize

plt.subplot(5, 2, 1)
sns.barplot(x=df.pop_rating, y=df.acousticness, palette = 'rocket')
plt.xlabel('Popularity Rating', fontsize = 12)
plt.ylabel('Acousticness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 2)
sns.barplot(x=df.pop_rating, y=df['danceability'], palette='Blues_d')
plt.xlabel('Popularity Rating', fontsize=12)
plt.ylabel('Danceability', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 3)
sns.barplot(x=df.pop_rating, y=df['duration_ms'], palette='CMRmap')
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('duration_ms', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 4)
sns.barplot(x=df.pop_rating, y=df['energy'], palette='nipy_spectral')
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('Energy', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 5)
sns.barplot(x=df.pop_rating, y=df['instrumentalness'], palette='flag')
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('Instrumentalness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 6)
sns.barplot(x=df.pop_rating, y=df['liveness'], palette='autumn')
plt.xlabel("Popularity Rating", fontsize=12)
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('Liveness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 7)
sns.barplot(x=df.pop_rating, y=df['loudness'], palette='inferno')
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('Loudness', fontsize = 12)
plt.ylim(-10, 0)
plt.grid()

plt.subplot(5, 2, 8)
sns.barplot(x=df.pop_rating, y=df['speechiness'], palette='magma')
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('Speechiness', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 9)
sns.barplot(x=df.pop_rating, y=df['tempo'], palette='rainbow')
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('Tempo', fontsize = 12)
plt.grid()

plt.subplot(5, 2, 10)
sns.barplot(x=df.pop_rating, y=df['valence'], palette='seismic')
plt.xlabel("Popularity Rating", fontsize=12)
plt.ylabel('Valence', fontsize = 12)
plt.grid()

plt.suptitle('Popularity Rating Relation to Music Attributes', fontsize = 20)
plt.show()

# %% [markdown]
# !!To be filled out!!

# %% [markdown]
# ## Data Preprocessing

# %% [raw]
# col = df.columns.to_list()

# %% [raw]
# # One Hot Encode the following features
# onehot_enc = ['mode', 'key', 'time_signature', 'pop_rating']

# %% [raw]
# continuous_data = [i for i in col if i not in onehot_enc]

# %% [markdown]
# First, we're going to try without the categorical pop_rating column

# %%
df_cont = df.copy().reset_index(drop=True)
df_cont.head()
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness   key  \
# 0        0.1010         0.748     237667.0   0.666          0.000653   6.0
# 1        0.1910         0.608     243667.0   0.664          0.042700   5.0
# 2        0.0786         0.470     157500.0   0.828          0.000000   9.0
# 3        0.3160         0.336     207354.0   0.861          0.000107  11.0
# 4        0.1480         0.790     174189.0   0.722          0.000000   1.0
#
#    liveness  loudness  mode  popularity  speechiness    tempo  time_signature  \
# 0    0.0976    -6.094   0.0        47.0       0.0833  114.982             4.0
# 1    0.1200    -8.261   0.0        35.0       0.0435  100.011             4.0
# 2    0.1780    -6.280   1.0        55.0       0.0700   96.149             4.0
# 3    0.2160    -3.274   1.0        41.0       0.1020  179.142             4.0
# 4    0.1720    -4.149   0.0        49.0       0.0678   98.109             4.0
#
#    valence  release_year pop_rating
# 0    0.359          2018  Unpopular
# 1    0.513          2018  Unpopular
# 2    0.856          2018    Popular
# 3    0.789          2019  Unpopular
# 4    0.948          2018  Unpopular

# %%
# Drop release year as we don't want it to be a factor in the prediction
index = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness',
         'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 
         'time_signature', 'valence', 'popularity']
df_cont.drop('pop_rating', inplace=True, axis=1)
df_cont = df_cont.reindex(columns=index)
df_cont.head(3)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.1010         0.748     237667.0   0.666          0.000653  6.0
# 1        0.1910         0.608     243667.0   0.664          0.042700  5.0
# 2        0.0786         0.470     157500.0   0.828          0.000000  9.0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0976    -6.094   0.0       0.0833  114.982             4.0    0.359
# 1    0.1200    -8.261   0.0       0.0435  100.011             4.0    0.513
# 2    0.1780    -6.280   1.0       0.0700   96.149             4.0    0.856
#
#    popularity
# 0        47.0
# 1        35.0
# 2        55.0

# %%
x = pd.get_dummies(df_cont['mode'])

# %%
df_cont = pd.concat([df_cont, x], axis=1)
df_cont.head(3)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.1010         0.748     237667.0   0.666          0.000653  6.0
# 1        0.1910         0.608     243667.0   0.664          0.042700  5.0
# 2        0.0786         0.470     157500.0   0.828          0.000000  9.0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0976    -6.094   0.0       0.0833  114.982             4.0    0.359
# 1    0.1200    -8.261   0.0       0.0435  100.011             4.0    0.513
# 2    0.1780    -6.280   1.0       0.0700   96.149             4.0    0.856
#
#    popularity  0.0  1.0
# 0        47.0    1    0
# 1        35.0    1    0
# 2        55.0    0    1

# %%
df_cont.rename(columns = {0.0: 'major key', 1.0: 'minor key'}, inplace=True)
df_cont.drop('mode', inplace=True, axis=1)

# %%
index = ['acousticness', 'danceability', 'duration_ms', 'energy', 'instrumentalness',
         'key', 'liveness', 'loudness', 'mode', 'speechiness', 'tempo', 
         'time_signature', 'valence', 'major key', 
         'minor key','popularity']
df_cont = df_cont.reindex(columns=index)
df_cont.drop('mode', inplace=True, axis=1)
df_cont.head(3)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.1010         0.748     237667.0   0.666          0.000653  6.0
# 1        0.1910         0.608     243667.0   0.664          0.042700  5.0
# 2        0.0786         0.470     157500.0   0.828          0.000000  9.0
#
#    liveness  loudness  speechiness    tempo  time_signature  valence  \
# 0    0.0976    -6.094       0.0833  114.982             4.0    0.359
# 1    0.1200    -8.261       0.0435  100.011             4.0    0.513
# 2    0.1780    -6.280       0.0700   96.149             4.0    0.856
#
#    major key  minor key  popularity
# 0          1          0        47.0
# 1          1          0        35.0
# 2          0          1        55.0

# %% [markdown]
# ### Splitting the Data

# %%
Y = df_cont['popularity']
X = df_cont.iloc[:, 0:-1]
print("The shape of X:", X.shape)
print("The shape of Y:", Y.shape)
# Out:
# The shape of X: (36435, 14)
# The shape of Y: (36435,)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=0)

print("The shape of x_train:", x_train.shape)
print("The shape of x_test:", x_test.shape)
print("The shape of y_train:", y_train.shape)
print("The shape of y_test:", y_test.shape)
# Out:
# The shape of x_train: (29148, 14)
# The shape of x_test: (7287, 14)
# The shape of y_train: (29148,)
# The shape of y_test: (7287,)

# %% [markdown]
# *change* Now that the data has been split with train_test_split, we can fit the training data and calculate the R2 score. This process, and all the similar ones to follow, is timed to get an understanding of the computational requirements for each model.
#
# In addition to the standard R2 score, I also created a custom loss function to give a more concrete perspective on the model performance. This function, custom_loss, calculates counts for different levels of error between the predicted values and the actual test values, and also gives an overall average of the differences between predicted and actual.

# %%
# This function only works with the continuous models, not with classifiers
def loss_function(predicts, truths):
    zipped = zip(predicts, truths)
    zipped_list = list(zipped)
    differences = {'Less than 5': 0, '5 - 10': 0, 'More than 10': 0, 'Average Error': 0}
    sum = 0

    for pair in zipped_list:
        sum += abs(pair[0] - pair[1])
        if abs(pair[0] - pair[1]) < 5:
            differences['Less than 5'] += 1
        elif 5 <= abs(pair[0] - pair[1]) < 10:
            differences['5 - 10'] += 1
        else:
            differences['More than 10'] += 1
            
    differences['Average Error'] = sum / len(zipped_list)
     
    return differences

# %% [markdown]
# *change* With the custom loss function set and the data split, we can begin running the models.

# %%
# %%time

lr = LinearRegression()
lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

print(lr.score(x_test, y_test))
# Out:
# 0.04190065431881562
# CPU times: user 32.1 ms, sys: 5.95 ms, total: 38.1 ms
# Wall time: 19.6 ms

# %%
loss_function(y_pred, y_test)
# Out:
# {'Less than 5': 1987,
#  '5 - 10': 1749,
#  'More than 10': 3551,
#  'Average Error': 11.672639816814572}

# %% [markdown]
# ** CHANGE** The score for the model above is not very good. On the other hand, the custom metric isn't as bad as the score would lead one to believe. There may be over 16,000 predictions well off the mark, but a good many were reasonably accurate, and the average difference isn't terrible.
#
# To take it a step further, let's see what happens when using the categoricals by using one hot encoding with .get_dummies(). For this step, I decided to drop the artist_name column. While song popularity is often correlated with artist popularity, the hope is for this model to work just as well on an artist it hasn't seen before. Part of the goal is to be able to discover new talent, and that becomes more difficult if the algorithm is inclined to discredit a song just because it doesn't recognize the artist. Therefore, the column is dropped for training purposes. This new dataset is stored as df_encoded.

# %% [markdown]
# ## Preprocessing

# %%
df_cat = df.copy().reset_index()
df_cat.drop(['index', 'popularity', 'release_year'], inplace=True, axis=1)
df_cat.head(3)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.1010         0.748     237667.0   0.666          0.000653  6.0
# 1        0.1910         0.608     243667.0   0.664          0.042700  5.0
# 2        0.0786         0.470     157500.0   0.828          0.000000  9.0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence  \
# 0    0.0976    -6.094   0.0       0.0833  114.982             4.0    0.359
# 1    0.1200    -8.261   0.0       0.0435  100.011             4.0    0.513
# 2    0.1780    -6.280   1.0       0.0700   96.149             4.0    0.856
#
#   pop_rating
# 0  Unpopular
# 1  Unpopular
# 2    Popular

# %% [raw]
# ''''col_to_drop = list(df_cat.iloc[:, :5].columns.values)
# col_to_drop += ['liveness', 'loudness', 'speechiness', 'tempo', 'valence', 'pop_rating', 'time_signature']
# df_cat_toencode = df_cat.drop(col_to_drop, axis=1)
# #list_to_encode = list(df_cat_toencode.columns.values)
# #list_to_encode''''

# %% [raw]
# ''x = pd.get_dummies(df_cat_toencode, columns=df_cat_toencode.columns.values)
# x.sample()'''

# %% [raw]
# '''df_cat = pd.concat([df_cat, x], axis=1)
# df_cat.drop(['key', 'mode', 'time_signature'], axis=1, inplace=True)
# df_cat.columns'''

# %% [raw]
# '''cols = ['key', 'mode', 'time_signature', 'pop_rating']
# df_cat[cols] = df_cat[cols].apply(lambda x: x.astype('category'))'''

# %%
# Replace Ordinal Values
df_cat['pop_rating'] = df_cat['pop_rating'].replace(('Very Popular', 'Popular', 'Unpopular'), (3, 2, 1))
df_cat['pop_rating'].value_counts()
# Out:
# 1    27969
# 2     8278
# 3      188
# Name: pop_rating, dtype: int64

# %% [markdown]
# ### Splitting and Normalizing the data
#
# All attribute columns range between 0 and 1, except for duration_ms, loudness, tempo, and release_year. Let's normalize them.

# %%
YY = df_cat['pop_rating']
XX = df_cat.drop('pop_rating', axis=1)

print(XX.shape)
print(YY.shape)
# Out:
# (36435, 13)
# (36435,)

# %%
XX.head(3)
# Out:
#    acousticness  danceability  duration_ms  energy  instrumentalness  key  \
# 0        0.1010         0.748     237667.0   0.666          0.000653  6.0
# 1        0.1910         0.608     243667.0   0.664          0.042700  5.0
# 2        0.0786         0.470     157500.0   0.828          0.000000  9.0
#
#    liveness  loudness  mode  speechiness    tempo  time_signature  valence
# 0    0.0976    -6.094   0.0       0.0833  114.982             4.0    0.359
# 1    0.1200    -8.261   0.0       0.0435  100.011             4.0    0.513
# 2    0.1780    -6.280   1.0       0.0700   96.149             4.0    0.856

# %%
YY.head()
# Out:
# 0    1
# 1    1
# 2    2
# 3    1
# 4    1
# Name: pop_rating, dtype: category
# Categories (3, int64): [1, 2, 3]

# %% [markdown]
# The target data is imbalanced, so we'll implement SMOTE.

# %%
# from imblearn.over_sampling import SMOTE

sn = SMOTE(random_state=0)

sn.fit(XX, YY)

x_resampled, y_resampled = sn.fit_resample(XX, YY)

print(x_resampled.shape)
print(y_resampled.shape)
# Out:
# (83907, 13)
# (83907,)

# %%
x_train, x_test, y_train, y_test = train_test_split(x_resampled, y_resampled, test_size=0.25, random_state=0)

print("The shape of x_train:", x_train.shape)
print("The shape of x_test:", x_test.shape)
print("The shape of y_train:", y_train.shape)
print("The shape of y_test:", y_test.shape)
print()
print(y_train.value_counts())
print()
print(y_test.value_counts())
# Out:
# The shape of x_train: (62930, 13)
# The shape of x_test: (20977, 13)
# The shape of y_train: (62930,)
# The shape of y_test: (20977,)
#
# 1    21035
# 2    20972
# 3    20923
# Name: pop_rating, dtype: int64
#
# 3    7046
# 2    6997
# 1    6934
# Name: pop_rating, dtype: int64

# %%
x_test.isna().sum()
# Out:
# acousticness        0
# danceability        0
# duration_ms         0
# energy              0
# instrumentalness    0
# key                 0
# liveness            0
# loudness            0
# mode                0
# speechiness         0
# tempo               0
# time_signature      0
# valence             0
# dtype: int64

# %%
lr = LinearRegression()
lr.fit(x_train, y_train)

y_pred = lr.predict(x_test)

print(lr.score(x_test, y_test))
# Out:
# 0.15891425942788384

# %%
cvals = cross_val_score(lr, XX, YY, cv=6)

# check the results
print(cvals)
print('The mean cross-validation score is: {num:.{dig}f}'.format\
      (num=np.mean(cvals), dig=4))
# Out:
# [-0.15134531 -0.08163616 -0.03986326  0.00880856 -0.01406349 -0.13214603]
# The mean cross-validation score is: -0.0684

# %% [markdown]
# ## Build Classification Model

# %%
# Basic decision tree
model1 = DecisionTreeClassifier(max_depth=20, random_state=25)
model1.fit(x_train, y_train)

y_pred = model1.predict(x_test)

print(accuracy_score(y_test, y_pred))
# Out:
# 0.8312914144062544

# %%
params = {'max_depth': [2, 10, 20, 40, 50],
         'min_samples_leaf': np.arange(1, 10, 2),}

model1 = DecisionTreeClassifier(random_state=0)

model1_cv = GridSearchCV(model1, params, cv=6)

model1_cv.fit(x_train, y_train)

print(model1_cv.best_params_)
print('The average runtime is: ', np.mean(model1_cv.cv_results_['mean_fit_time']))
print('The best score is: ', model1_cv.best_score_)
# Out:
# {'max_depth': 40, 'min_samples_leaf': 1}
# The average runtime is:  0.5366194581985473
# The best score is:  0.8316064976307191

# %%
p = model1_cv.best_estimator_.predict(x_test)

print(accuracy_score(y_test, p))
# Out:
# 0.8424464890117748

# %% [markdown]
# ### Bagging

# %%
# %%time

from sklearn.ensemble import BaggingClassifier

tree = DecisionTreeClassifier(max_depth=2, random_state=0)
model2 = BaggingClassifier(base_estimator=tree, n_estimators=100, random_state=0)

bag_cv = cross_val_score(model2, x_train, y_train, cv=6)
model2.fit(x_train, y_train)
y_pred = model2.predict(x_test)

print(bag_cv)
print('The mean cross-validation score is: {num:.{dig}f}'.format\
      (num=np.mean(bag_cv), dig=4))
cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = small_figsize
sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.show()
# Out:
# [0.53989894 0.534274   0.53499237 0.548627   0.53442029 0.53308543]
# The mean cross-validation score is: 0.5375
# CPU times: user 49.7 s, sys: 558 ms, total: 50.2 s
# Wall time: 51.5 s

# %%
# Accuracy and Classification Report
print(accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# 0.5430709825046479
#               precision    recall  f1-score   support
#
#            1       0.50      0.38      0.43      6934
#            2       0.51      0.50      0.50      6997
#            3       0.59      0.75      0.66      7046
#
#     accuracy                           0.54     20977
#    macro avg       0.53      0.54      0.53     20977
# weighted avg       0.54      0.54      0.53     20977

# %% [markdown]
# ### Random Forest

# %%
# %%time

model3 = RandomForestClassifier(n_estimators=100, random_state=25)
model3.fit(x_train, y_train)

y_pred = model3.predict(x_test)

print(accuracy_score(y_pred, y_test))
# Out:
# 0.9103303618248558
# CPU times: user 14.9 s, sys: 174 ms, total: 15 s
# Wall time: 15.3 s

# %%
model3_params = {'n_estimators': [100, 300, 350],
            'max_depth': [2, 5, 100],
            'min_samples_leaf': [1, 2]}

model3_new = RandomForestClassifier(random_state=25)

model3_cv = GridSearchCV(model3_new, model3_params, n_jobs=-1, cv=6)

model3_cv.fit(x_train, y_train)

print(model3_cv.best_params_)
# Out:
# {'max_depth': 100, 'min_samples_leaf': 1, 'n_estimators': 350}

# %%
# %%time

model3 = RandomForestClassifier(max_depth=100, n_estimators=350, min_samples_leaf=1, random_state=25)

model3.fit(x_train, y_train)

y_pred = model3.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = (12, 7)
sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.show()
# Out:
# CPU times: user 51.4 s, sys: 579 ms, total: 52 s
# Wall time: 52.5 s

# %%
# Accuracy and Classification Report
print(accuracy_score(y_test, y_pred))
print()
print(classification_report(y_test, y_pred))
# print()
# loss_function(y_pred, y_test)
# Out:
# 0.9126185822567574
#
#               precision    recall  f1-score   support
#
#            1       0.84      0.91      0.87      6934
#            2       0.90      0.83      0.86      6997
#            3       1.00      1.00      1.00      7046
#
#     accuracy                           0.91     20977
#    macro avg       0.91      0.91      0.91     20977
# weighted avg       0.91      0.91      0.91     20977

# %% [markdown]
# The confusion matrix and classification report look very promising!

# %% [markdown]
# ### Boosting Models

# %% [markdown]
# I want to explore if the model improves when using AdaBoost and Gradient Boosting.

# %%
# %%time

dtc = DecisionTreeClassifier(max_depth=1, random_state=25)

model4 = AdaBoostClassifier(base_estimator=dtc, n_estimators=200)

model4.fit(x_train, y_train)

y_pred = model4.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = (12, 7)
sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.show()
# Out:
# CPU times: user 15 s, sys: 137 ms, total: 15.1 s
# Wall time: 15.3 s

# %%
# Accuracy and Classification Report
print(accuracy_score(y_test, y_pred))
print()
print(classification_report(y_test, y_pred))
# Out:
# 0.711350526767412
#
#               precision    recall  f1-score   support
#
#            1       0.69      0.79      0.74      6934
#            2       0.65      0.50      0.56      6997
#            3       0.78      0.85      0.81      7046
#
#     accuracy                           0.71     20977
#    macro avg       0.71      0.71      0.70     20977
# weighted avg       0.71      0.71      0.70     20977

# %%
# %%time

model5 = GradientBoostingClassifier(max_depth=3, n_estimators=200, random_state=0)

model5.fit(x_train, y_train)

y_pred = model5.predict(x_test)

cm = confusion_matrix(y_test, y_pred)
plt.rcParams['figure.figsize'] = (12, 7)
sns.heatmap(cm, annot=True)
plt.title("Confusion Matrix")
plt.show()
# Out:
# CPU times: user 1min 42s, sys: 1.71 s, total: 1min 44s
# Wall time: 1min 45s

# %%
# Accuracy and Classification Report
print(accuracy_score(y_test, y_pred))
print()
print(classification_report(y_test, y_pred))
# Out:
# 0.8207560661677075
#
#               precision    recall  f1-score   support
#
#            1       0.75      0.92      0.82      6934
#            2       0.87      0.59      0.70      6997
#            3       0.87      0.96      0.91      7046
#
#     accuracy                           0.82     20977
#    macro avg       0.83      0.82      0.81     20977
# weighted avg       0.83      0.82      0.81     20977

# %% [markdown]
# For this dataset the Random Forest Model seems to work best. So we'll be going with that one.

# %%
# Save the Random Forest model in a pickle file
filepath = 'music_pop_predictor.pkl'
with open(filepath, 'wb') as f:
    pickle.dump(model3, f)
'''with gzip.open(filepath, 'wb') as f:
    pickled = pickle.dumps(model3)
    optimized_pickle = pickletools.optimize(pickled)
    f.write(optimized_pickle)'''
# Out:
# "with gzip.open(filepath, 'wb') as f:\n    pickled = pickle.dumps(model3)\n    optimized_pickle = pickletools.optimize(pickled)\n    f.write(optimized_pickle)"

# %%
'''# to deserialize/load back:
with gzip.open(filepath, 'rb') as f:
    p = pickle.Unpickler(f)
    model = p.load()'''
# Out:
# "# to deserialize/load back:\nwith gzip.open(filepath, 'rb') as f:\n    p = pickle.Unpickler(f)\n    model = p.load()"

# %%
col_list = x_test.columns.tolist()
col_list
# Out:
# ['acousticness',
#  'danceability',
#  'duration_ms',
#  'energy',
#  'instrumentalness',
#  'key',
#  'liveness',
#  'loudness',
#  'mode',
#  'speechiness',
#  'tempo',
#  'time_signature',
#  'valence']

# %%
filepath = 'music_pop_predictor.pkl'
with open(filepath, 'rb') as f:
    model = pickle.load(f)

y_pred = model.predict(x_test)

# %%
x = df_cat[df_cat['pop_rating'] == 3]
x
# Out:
#        acousticness  danceability  duration_ms  energy  instrumentalness  \
# 14235        0.0323         0.731     220454.0   0.794          0.000026
# 17757        0.5710         0.765     129600.0   0.327          0.047900
# 21009        0.0175         0.657     341574.0   0.746          0.000000
# 21010        0.0175         0.657     341574.0   0.746          0.000000
# 21011        0.0175         0.657     341574.0   0.746          0.000000
# ...             ...           ...          ...     ...               ...
# 36403        0.2690         0.737     192453.0   0.747          0.000000
# 36404        0.2690         0.737     192453.0   0.747          0.000000
# 36410        0.3870         0.836     240082.0   0.621          0.000092
# 36411        0.3870         0.836     240082.0   0.621          0.000092
# 36413        0.0135         0.421     175424.0   0.653          0.000000
#
#         key  liveness  loudness  mode  speechiness    tempo  time_signature  \
# 14235   0.0    0.1120    -5.126   0.0       0.0522  139.994             4.0
# 17757   6.0    0.0787    -8.029   1.0       0.2770   74.931             4.0
# 21009   1.0    0.1070    -6.277   1.0       0.0464  136.887             4.0
# 21010   1.0    0.1070    -6.277   1.0       0.0464  136.887             4.0
# 21011   1.0    0.1070    -6.277   1.0       0.0464  136.887             4.0
# ...     ...       ...       ...   ...          ...      ...             ...
# 36403  10.0    0.2190    -4.818   1.0       0.0323  105.943             4.0
# 36404  10.0    0.2190    -4.818   1.0       0.0323  105.943             4.0
# 36410   1.0    0.1040    -4.685   0.0       0.0892  101.995             4.0
# 36411   1.0    0.1040    -4.685   0.0       0.0892  101.995             4.0
# 36413   9.0    0.1140    -4.850   0.0       0.3980   78.600             4.0
#
#        valence pop_rating
# 14235    0.356          3
# 17757    0.292          3
# 21009    0.467          3
# 21010    0.467          3
# 21011    0.467          3
# ...        ...        ...
# 36403    0.447          3
# 36404    0.447          3
# 36410    0.762          3
# 36411    0.762          3
# 36413    0.733          3
#
# [188 rows x 14 columns]
